# %% [markdown]
# ### Realtime Object Detection

# %% [markdown]
# Detects objects in realtime video streaming via webcam

# %% [markdown]
# #### Import libraries for preprocessing and annotation

# %%
import numpy as np
import cv2
from pathlib import Path
from IPython.display import Image
import torch

# %% [markdown]
# #### Load pretrained models

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\User/.cache\torch\hub\master.zip
# Matplotlib is building the font cache; this may take a moment.
# YOLOv5  2023-4-15 Python-3.9.8 torch-1.8.1+cpu CPU
# requirements: C:\Users\User\.cache\torch\hub\requirements.txt not found, check failed.
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# #### Run object detection on example image

# %%
imgs = ['https://ultralytics.com/images/zidane.jpg']
Image(url=imgs[0])
# Out:
# <img src="https://ultralytics.com/images/zidane.jpg"/>

# %%
results = model(imgs)
results.print()
results.save(".")
# Out:
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 7335.7ms pre-process, 1449.2ms inference, 219.9ms NMS per image at shape (1, 3, 384, 640)
# Saved 1 image to runs\detect\exp3

# %%
Image(filename='runs\detect\exp\zidane.jpg')

# %% [markdown]
# #### Run object detection on realtime video via webcam

# %%
print("Press q to exit the object detection window!")
cap = cv2.VideoCapture(0)
while True:
    ret, image_np = cap.read()
    results = model(image_np)
    df_result = results.pandas().xyxy[0]
    dict_result = df_result.to_dict()
    scores = list(dict_result["confidence"].values())
    labels = list(dict_result["name"].values())
    
    list_boxes = list()
    for dict_item in df_result.to_dict('records'):
        list_boxes.append(list(dict_item.values())[:4])
    count = 0
    
    for xmin, ymin, xmax, ymax in list_boxes:
        image_np = cv2.rectangle(image_np, pt1=(int(xmin),int(ymin)), pt2=(int(xmax),int(ymax)), \
                                 color=(255,0, 0), thickness=2)
        cv2.putText(image_np, f"{labels[count]}: {round(scores[count], 2)}", (int(xmin), int(ymin)-10), \
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
        count = count + 1
        
    cv2.imshow('Object Detector', image_np);
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        print("The window has been exited!")
        break
# Out:
# Press q to exit the object detection window!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 5
#       3 while True:
#       4     ret, image_np = cap.read()
# ----> 5     results = model(image_np)
#       6     df_result = results.pandas().xyxy[0]
#       7     dict_result = df_result.to_dict()
#
# File C:\kandikits\realtime-object-detection\object-detection-env\lib\site-packages\torch\nn\modules\module.py:889, in Module._call_impl(self, *input, **kwargs)
#     887     result = self._slow_forward(*input, **kwargs)
#     888 else:
# --> 889     result = self.forward(*input, **kwargs)
#     890 for hook in itertools.chain(
#     891         _global_forward_hooks.values(),
#     892         self._forward_hooks.values()):
#     893     hook_result = hook(self, input, result)
#
# File C:\kandikits\realtime-object-detection\object-detection-env\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.__class__():
# ---> 27         return func(*args, **kwargs)
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:688, in AutoShape.forward(self, ims, size, augment, profile)
#     686     im, f = np.asarray(exif_transpose(im)), getattr(im, 'filename', f) or f
#     687 files.append(Path(f).with_suffix('.jpg').name)
# --> 688 if im.shape[0] < 5:  # image in CHW
#     689     im = im.transpose((1, 2, 0))  # reverse dataloader .transpose(2, 0, 1)
#     690 im = im[..., :3] if im.ndim == 3 else cv2.cvtColor(im, cv2.COLOR_GRAY2BGR)  # enforce 3ch input
#
# AttributeError: 'NoneType' object has no attribute 'shape'
